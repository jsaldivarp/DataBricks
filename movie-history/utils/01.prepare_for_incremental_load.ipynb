-- %% [markdown]
-- ##Elimina y vuelve a crear todas las bases de datos

-- %%
--Eliminamos las bases de datos
drop database if exists movie_silver cascade;

-- %%
create schema if not exists movie_silver
managed location "abfss://silver@lsdata01.dfs.core.windows.net";

-- %%
drop database if exists movie_gold cascade;

-- %%
--Creamos nuevamente las bases de datos
create schema if not exists movie_gold
managed location "abfss://gold@lsdata01.dfs.core.windows.net";
