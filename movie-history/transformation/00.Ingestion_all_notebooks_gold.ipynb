# %%
var_result_01 = dbutils.notebook.run("01.results_movie_genre_language", 0)
var_result_02 = dbutils.notebook.run("02.results_country_prod_company", 0)
var_result_03 = dbutils.notebook.run("03.results_group_movie_genre", 0)
var_result_04 = dbutils.notebook.run("04.result_group_movie_country", 0)

# %%
var_result_01

# %%
var_result_02

# %%
var_result_03

# %%
var_result_04
