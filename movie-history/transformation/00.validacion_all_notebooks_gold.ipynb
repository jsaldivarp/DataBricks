-- %%
use movie_gold

-- %%
Select 'results_movie_genre_language' tabla_name, file_date, count(1) from movie_gold.results_movie_genre_language group by file_date
union all
Select 'results_country_prod_company' tabla_name, file_date, count(1) from movie_gold.results_country_prod_company group by file_date
union all
Select 'result_group_movie_genre' tabla_name, file_date, count(1) from movie_gold.result_group_movie_genre group by file_date
union all
Select 'result_group_movie_country' tabla_name, file_date, count(1) from movie_gold.result_group_movie_country group by file_date
--union all
--Select 'results_movie' tabla_name, file_date, count(1) from movie_gold.results_movie group by file_date

-- %%
Select * from movie_gold.results_movie

-- %%
Select 'result_group_movie_genre' tabla_name, file_date, count(1) from movie_gold.result_group_movie_genre group by file_date
