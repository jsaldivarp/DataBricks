# %%
var_result_01 = dbutils.notebook.run("01.Ingestion File Movie", 0)
var_result_02 = dbutils.notebook.run("02.Ingestion File Language", 0)
var_result_03 = dbutils.notebook.run("03. Ingestion File genre", 0)
var_result_04 = dbutils.notebook.run("04. Ingestion File country", 0)
var_result_05 = dbutils.notebook.run("05. Ingestion File person", 0)
var_result_06 = dbutils.notebook.run("06. Ingestion File movie_genre", 0)
var_result_07 = dbutils.notebook.run("07. Ingestion File movie_cast", 0)
var_result_08 = dbutils.notebook.run("08. Ingestion File language_role", 0)
var_result_09 = dbutils.notebook.run("09. Ingestion folder_production_company", 0)
var_result_10 = dbutils.notebook.run("10. Ingestion folder_movie_company", 0)
var_result_11 = dbutils.notebook.run("11. Ingestion folder_movie_language", 0)
var_result_12 = dbutils.notebook.run("12. Ingestion folder_production_country", 0)

# %%
var_result_01

# %%
var_result_02

# %%
var_result_03

# %%
var_result_04

# %%
var_result_05

# %%
var_result_06

# %%
var_result_07

# %%
var_result_08

# %%
var_result_09

# %%
var_result_10

# %%
var_result_11

# %%
var_result_12
