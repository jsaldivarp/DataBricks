# %%
dbutils.secrets.help()

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list(scope = "js-sc-databricks-us" )

# %%
dbutils.secrets.get(scope = "js-sc-databricks-us", key = "secret-access-key")

# %%
var_access_key = dbutils.secrets.get(scope = "js-sc-databricks-us", key = "secret-access-key")

# %%
spark.conf.set(
    "fs.azure.account.key.lsdata01.dfs.core.windows.net",
               var_access_key
)

# %%
display(dbutils.fs.ls("abfss://demo@lsdata01.dfs.core.windows.net"))

# %%
dbutils.fs.ls("abfss://demo@lsdata01.dfs.core.windows.net/")

# %%
dbutils.fs.ls("abfss://gold@lsdata01.dfs.core.windows.net/")
