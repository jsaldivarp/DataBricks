-- %%
GRANT USE CATALOG ON CATALOG js_ws_databricks_us TO `js-adatafactory-movie-us`;
GRANT USE SCHEMA ON SCHEMA js_ws_databricks_us.movie_silver TO `js-adatafactory-movie-us`;
GRANT SELECT, MODIFY ON SCHEMA js_ws_databricks_us.movie_silver TO `js-adatafactory-movie-us`;

-- %%
SHOW GRANTS ON SCHEMA js_ws_databricks_us.movie_silver;
