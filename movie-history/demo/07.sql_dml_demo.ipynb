-- %%
SHOW DATABASES

-- %%
select current_database();

-- %%
use movie_silver;
show tables;

-- %%
select * from movie_silver.movies
limit 100;

-- %%
select *
from movie_silver.movies m 
where m.year_release_date = 2015
      and m.vote_average >= 7.5
order by m.vote_average desc
limit 100;
