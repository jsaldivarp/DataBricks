# %%
#Variables con las rutas
bronze_folder_path = "abfss://bronze@lsdata01.dfs.core.windows.net"
silver_folder_path = "abfss://silver@lsdata01.dfs.core.windows.net"
gold_folder_path   = "abfss://gold@lsdata01.dfs.core.windows.net"

#parametro de fecha de data
v_file_date = "2024-12-16"

# %% [markdown]
# #####{bronze_folder_path}
# #####{silver_folder_path}
# #####{gold_folder_path}
#
# #####{v_file_date}
